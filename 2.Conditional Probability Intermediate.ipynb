# %% [markdown]
# We started our journey into conditional probability and managed to derive two important formulae:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Important summary of the notation we know so far:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# The analytics team of a store randomly sampled 2,000 customers in their database. They looked at customer behavior with respect to buying laptops and wireless mice to see if bundling them might increase sales. The results are summarized in the table below, where we have the events:
#
# * **L** is the event that the customer bought a laptop
# * **M** is the event that the customer bought a mouse
# * $L^C$ is the event that the customer didn't buy a laptop
# * $M^C$ is the event that the customer didn't buy a mouse
#
# ![image.png](attachment:image.png)
#
# Find:
#
# 1. **P(M)**, the probability that a customer buys a mouse.
# 2. **P(M|L)**, the probability that a customer buys a mouse given that they bought a laptop.
# 3. **P(M∩L)**, the probability that a customer buys both a mouse and a laptop.
# 4. **P(M∪L)**, the probability that a customer buys a mouse or a laptop
#
# **Answer**
#
# `p_m <- 515/2000
# p_m_given_l <- 32/90
# p_m_and_l <- 32/2000
# p_l <- 90/2000
# p_m_or_l <- p_m + p_l - p_m_and_l`

# %% [markdown]
# We considered the table below and found that **P(M|L)**, the probability that a customer buys a mouse given that they bought a laptop, was **32/90**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This formula mirrors what we have learned previously, but adds a conditional aspect to it. Conditional probabilities are still probabilities in the end, so they must also obey the same rules that "non-conditional" or **marginal** probabilities follow. However, we must be careful to note that that the relationship above applies for the event **A** and not the condition **B**. The complement of;
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
#
# **Answer**
#
# `p_b_given_m <- 0.1486
# p_c_given_l <- 0.0928
# p_non_b_given_c <- 0.7622
# p_non_b_given_m <- 1 - p_b_given_m
# p_non_c_given_l <- 1 - p_c_given_l
# p_b_given_c <- 1 - p_non_b_given_c`

# %% [markdown]
# We alluded to the fact that two similar-looking conditional probabilities, **P(A|B)** and **P(B|A)**
# have different interpretations. We'll discuss this idea a bit more in detail.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**
#
# `p_m_given_non_l <- 483/1910
# p_non_l_given_m <- 483/515
# p_m_and_non_l <- 483/2000
# p_non_l_and_m <- 483/2000` #P(M and non-L) is the same as P(non-L and M)

# %% [markdown]
# Previously, we found that the probability of an intersection could be expressed as a product of a conditional and a marginal probability:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# This formula takes on a familiar form to the multiplication rule. That is, the probability of an intersection of events can be expressed as the product of the two marginal probabilities:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The only difference that we have with this new equation is that one of the probabilities is now a conditional probability instead of a marginal one.

# %% [markdown]
# We said in the last screen that, in general, the two conditional probabilities **P(A|B)** and
# **P(B|A)** are not equal to each other. Despite this, we can still derive a useful relationship between the two. Just as we saw with the diagnostic test for HIV, both probabilities can be important to know.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The above equation tells us about the relationship between **P(A|B)** and
# **P(B|A)**. It is worth saying again that this formula works in general since the probability of the intersection between two events won't change. This relationship will come in handy later, but for now, we'll focus on the fact that the probability of an intersection can be written in two equivalent ways.
#
# To ground our formula, suppose we have a bowl with six green marbles and four red marbles. If we're drawing one marble at a time randomly and without replacement (meaning we don't put the marbles drawn back in the bowl), then what's the probability of getting a red marble on the first draw, followed by a green marble on the second draw?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**
#
# `p_ram <- 0.0822
# p_gl <- 0.0184
# p_ram_given_gl <- 0.0022
# p_gl_and_ram <- p_gl * p_ram_given_gl
# p_non_ram_given_gl <- 1 - p_ram_given_gl
# p_gl_and_non_ram <- p_gl * p_non_ram_given_gl
# p_gl_or_ram <- p_gl + p_ram - p_gl_and_ram`

# %% [markdown]
# We saw the multiplication rule in a slightly different form and that the probability of an intersection can be expressed in two similar ways:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# These formula are similar to the multiplication rule. We'll see how this formula can be simplified back to the product of two marginal probabilities. Let's consider an example where we roll a fair six-sided die twice and want to find **P(A∩B)**, where:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# By definition, independent events are events that do not affect the probability of each other. We finally learn what that "means" mathematically: if two events are independent of each other, it doesn't change the probability of their intersection if we condition on one. In fact, formula (3) is the mathematical definition for independence. If that equality does not hold, then we know that the two events **are not independent of each other**, or they are **dependent** on one another.

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**
#
# `k_and_l <- 'independent'
# l_and_m <- 'independent'
# k_and_m <- 'dependent'`

# %% [markdown]
# ![image.png](attachment:image.png)
#
# If any of the three relationships above does not hold, then **A** and **B** are dependent on each other.

# %% [markdown]
# In the above exercise, for instance, we considered rolling a fair six-sided die twice and saw events **K** and **M** were not independent, where: 4 - **K**: The die showed a 4 on the second roll. - **M**: The die showed an even number on the second roll.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# Calculate the given probabilities
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# **Answer**
#
#
# `l_and_m <- 'dependent'
# l_and_non_m <- 'dependent'`
#
# `p_l <- 90/2000
# p_m_given_l <- 32/90
# p_l_and_m <- p_l * p_m_given_l`
#
#
# `p_not_m_given_l <- 58/90
# p_l_and_non_m <- p_l * p_not_m_given_l`

# %% [markdown]
# We may have noticed that we've only considered two events. What will the multiplication rule look like if we have three events ? How do we find whether or not they are independent?

# %% [markdown]
# When we discussed the multiplication rule we explained that the rule can be extended for any number of events, provided they are all independent of each other.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Adding a third event adds a little more complexity. To find whether three events — **A**, **B**, **C** — are independent or not, we have to check two different kinds of independence. First, each event has to be independent one from all the others, which means the following relationships must be true:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Above, events A, B, C are independent in pairs — we say they are pairwise independent. The second condition is that they should be also independent all together, which mathematically means:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# If both conditions above hold, events A, B, C are said to be **mutually independent**.

# %% [markdown]
# It is important to note that having pairwise independence in the three events does not automatically mean that they will be mutually independent. We'll look at an example where three events satisfy the condition of pairwise independence, and yet they are not mutually independent. Let's say we toss a fair coin twice and consider the following three events, where:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**
#
# `p_et <- 0.0432
# p_ac <- 0.0172
# p_ps <- 0.0236
# p_et_and_ps <- p_et * p_ps
# p_et_and_ac <- p_et * p_ac
# p_ac_and_ps <- p_ac * p_ps
# p_et_and_ac_and_ps <- p_et * p_ac * p_ps`
